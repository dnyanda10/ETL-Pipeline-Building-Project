# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id= "184d6701bc5f4a8fad82818d37a43c8e", client_secret="032298edba2b4ff994d7ae7f0ac99066")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager,
                      requests_timeout=30)

# %%
playlist_link = "https://open.spotify.com/playlist/679wCT6dVMDBxrYa5NcrXL"

# %%
playlist_uri = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data ['items'][0]['track']['album']['id']
# Out:
# '2LnqsGJJZlzAr980A4facE'

# %%
data ['items'][0]['track']['album']['name']
# Out:
# 'I Like You (A Happier Song)'

# %%
data ['items'][0]['track']['album']['release_date']
# Out:
# '2024-02-15'

# %%
data ['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data ['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2LnqsGJJZlzAr980A4facE'

# %%
album_list = []
for row in data['items']:
     album_id = row['track']['album']['id']
     album_name = row['track']['album']['name']
     album_release_date = row ['track']['album']['release_date']
     album_total_tracks = row['track']['album']['total_tracks']
     album_url = row['track']['album']['external_urls']['spotify']
     album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
     album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '2LnqsGJJZlzAr980A4facE',
#   'name': 'I Like You (A Happier Song)',
#   'release_date': '2024-02-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2LnqsGJJZlzAr980A4facE'},
#  {'album_id': '2wd0Yajm2aZnG3uAYStKXz',
#   'name': 'Lonewalking',
#   'release_date': '2023-12-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2wd0Yajm2aZnG3uAYStKXz'},
#  {'album_id': '6FG36OzCS7uliuAGGgFUku',
#   'name': 'Strangers',
#   'release_date': '2024-11-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6FG36OzCS7uliuAGGgFUku'},
#  {'album_id': '0PRK8Gt08ZYl5XrxHF8KDm',
#   'name': "I Still Haven't Found What I'm Looking For",
#   'release_date': '2024-11-29',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/0PRK8Gt08ZYl5XrxHF8KDm'},
#  {'album_id': '0XJhqJBxqsGk5dJ10T5Hza',
#   'name': 'Stolen Dance',
#   'release_date': '2024-11-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0XJhqJBxqsGk5dJ10T5Hza'},
#  {'album_id': '5hvLByuh91UIymllv9nPen',
#   'name': 'Dancing In the Moonlight',
#   'release_date': '2024-10-18',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5hvLByuh91UIymllv9nPen'},
#  {'album_id': '1SbMzKZQDa627u3I93xnZ5',
#   'name': 'Last Night',
#   'release_date': '2024-11-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1SbMzKZQDa627u3I93xnZ5'},
#  {'album_id': '3QaSoEL5t50cmyWczGAAen',
#   'name': 'sad kiwis',
#   'release_date': '2025-01-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3QaSoEL5t50cmyWczGAAen'},
#  {'album_id': '5VuCI7SVbIPJHaIQiMEUaH',
#   'name': 'Ride The Wave',
#   'release_date': '2024-10-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5VuCI7SVbIPJHaIQiMEUaH'},
#  {'album_id': '1LsijdAt7Q1hAfpzWBCXDU',
#   'name': 'Alexandra',
#   'release_date': '2023-11-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1LsijdAt7Q1hAfpzWBCXDU'},
#  {'album_id': '3sd5FJyaVb399cvjE528Hl',
#   'name': 'Runaway',
#   'release_date': '2024-09-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3sd5FJyaVb399cvjE528Hl'},
#  {'album_id': '0QxvW9yoUzWOerSr2GOur2',
#   'name': 'falling in love',
#   'release_date': '2024-11-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0QxvW9yoUzWOerSr2GOur2'},
#  {'album_id': '0VMegFO4xL8yJ39mSjgGBK',
#   'name': 'Stick Season',
#   'release_date': '2024-08-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0VMegFO4xL8yJ39mSjgGBK'},
#  {'album_id': '4xav9e2yH3Se8zfZKGVkDI',
#   'name': 'Sicilia Mon Amour',
#   'release_date': '2024-07-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4xav9e2yH3Se8zfZKGVkDI'},
#  {'album_id': '4MWmHlxlgqEqWk9rAVYQpT',
#   'name': 'I Got It',
#   'release_date': '2024-08-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4MWmHlxlgqEqWk9rAVYQpT'},
#  {'album_id': '1O5txbsW7FZOhOdyB28Oxb',
#   'name': 'My Compass',
#   'release_date': '2024-10-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1O5txbsW7FZOhOdyB28Oxb'},
#  {'album_id': '7wO8ABcKtrlZUBY43jkZTp',
#   'name': 'A Game of Catch',
#   'release_date': '2024-08-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7wO8ABcKtrlZUBY43jkZTp'},
#  {'album_id': '2E7jd5gYvd4Qns1EgbRX3M',
#   'name': 'Milkshake',
#   'release_date': '2024-08-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2E7jd5gYvd4Qns1EgbRX3M'},
#  {'album_id': '0JbNkMCvpDeXpjD1rNOkyG',
#   'name': 'Golden Hour',
#   'release_date': '2025-01-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0JbNkMCvpDeXpjD1rNOkyG'},
#  {'album_id': '6kymuFaOY4yIpaf1BloeWP',
#   'name': 'Graffiti',
#   'release_date': '2025-01-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6kymuFaOY4yIpaf1BloeWP'},
#  {'album_id': '3sbULTTqwJhut4CU7xkBYi',
#   'name': 'Cry Me A River',
#   'release_date': '2021-10-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3sbULTTqwJhut4CU7xkBYi'},
#  {'album_id': '5KoUzy2helQ0q4FOBxQX5T',
#   'name': 'Peaches',
#   'release_date': '2021-06-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5KoUzy2helQ0q4FOBxQX5T'},
#  {'album_id': '5CW9FfcU52Cb7dhuKewgGR',
#   'name': 'Stay With Me',
#   'release_date': '2020-12-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5CW9FfcU52Cb7dhuKewgGR'},
#  {'album_id': '0XWObO4Iw9ft6iuCquqUim',
#   'name': 'I Like Me Better',
#   'release_date': '2020-09-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0XWObO4Iw9ft6iuCquqUim'},
#  {'album_id': '5QebQh3ubARVUvFo8x9JsI',
#   'name': 'Strawberry Milkshake',
#   'release_date': '2022-06-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5QebQh3ubARVUvFo8x9JsI'},
#  {'album_id': '4P0Osalw7TaQLM0JKIyHOy',
#   'name': 'Mr. Brightside',
#   'release_date': '2022-05-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4P0Osalw7TaQLM0JKIyHOy'},
#  {'album_id': '1KnSRTKOePuA8bk3J5rfZz',
#   'name': 'Summer',
#   'release_date': '2021-08-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1KnSRTKOePuA8bk3J5rfZz'},
#  {'album_id': '5F25JMKIZl6Zl4huvs6GtE',
#   'name': 'Ghost',
#   'release_date': '2022-01-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5F25JMKIZl6Zl4huvs6GtE'},
#  {'album_id': '1Xf5iUcZ58jNVHZk00bKGZ',
#   'name': 'close to me',
#   'release_date': '2021-02-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Xf5iUcZ58jNVHZk00bKGZ'},
#  {'album_id': '5IbPrWZci4TMA8HkkRZ9H6',
#   'name': 'Replay',
#   'release_date': '2025-04-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5IbPrWZci4TMA8HkkRZ9H6'},
#  {'album_id': '0h2vbPgmVGwauQM56MzOHO',
#   'name': 'Jazzy Wave',
#   'release_date': '2022-06-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0h2vbPgmVGwauQM56MzOHO'},
#  {'album_id': '3gV84dELFOmQI069rTzF6l',
#   'name': 'Margarita',
#   'release_date': '2025-04-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3gV84dELFOmQI069rTzF6l'},
#  {'album_id': '2XsNMs7FezfBjQJRPzL8uo',
#   'name': 'Just the Way You Are',
#   'release_date': '2022-04-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2XsNMs7FezfBjQJRPzL8uo'},
#  {'album_id': '4lvqAZXMcGkOgKZtecqT7i',
#   'name': 'Ice Cream',
#   'release_date': '2025-05-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4lvqAZXMcGkOgKZtecqT7i'},
#  {'album_id': '0iDUI76FF4wAyZGfTUDUlA',
#   'name': 'My Heart Will Go On',
#   'release_date': '2025-05-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0iDUI76FF4wAyZGfTUDUlA'},
#  {'album_id': '2jKCC3eHlHWTf45qgO1Flg',
#   'name': 'Sunset',
#   'release_date': '2025-05-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2jKCC3eHlHWTf45qgO1Flg'},
#  {'album_id': '5TBz1aTxXLnbdmu7MpNEGd',
#   'name': 'Lonely',
#   'release_date': '2025-05-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5TBz1aTxXLnbdmu7MpNEGd'},
#  {'album_id': '0o0jNn9Xe2NibVNgdAfKUY',
#   'name': 'Mon Amour',
#   'release_date': '2025-06-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0o0jNn9Xe2NibVNgdAfKUY'},
#  {'album_id': '0N2J0C33sPBp0dl21SK1MR',
#   'name': 'Sunroof',
#   'release_date': '2024-01-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0N2J0C33sPBp0dl21SK1MR'},
#  {'album_id': '0OwusBk6vGwXwAYgd9qOPx',
#   'name': 'Romance',
#   'release_date': '2025-06-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0OwusBk6vGwXwAYgd9qOPx'},
#  {'album_id': '55fATg8Bg9l4I8YQxKjsmm',
#   'name': "You're Beautiful",
#   'release_date': '2021-11-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/55fATg8Bg9l4I8YQxKjsmm'},
#  {'album_id': '58lNXjCh1zf7GB1azd3noK',
#   'name': 'Park Walk',
#   'release_date': '2025-05-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/58lNXjCh1zf7GB1azd3noK'},
#  {'album_id': '37JxZdDpiPKb0R2Bg2TvPR',
#   'name': 'Let Me Love You',
#   'release_date': '2025-02-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/37JxZdDpiPKb0R2Bg2TvPR'},
#  {'album_id': '3kWqqcp39FcFexBr8zrpE8',
#   'name': 'Hot Air Balloon',
#   'release_date': '2025-05-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3kWqqcp39FcFexBr8zrpE8'},
#  {'album_id': '3IJI5YBdG8VM6mAdAJZAAt',
#   'name': 'Little Talks',
#   'release_date': '2022-04-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3IJI5YBdG8VM6mAdAJZAAt'},
#  {'album_id': '7fX5VTRaI3RSfcfrhfxxsQ',
#   'name': 'Fantasy Train',
#   'release_date': '2025-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7fX5VTRaI3RSfcfrhfxxsQ'},
#  {'album_id': '6TrajwWKKi3PWRcDbtrV6h',
#   'name': 'Something Just Like This',
#   'release_date': '2025-06-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6TrajwWKKi3PWRcDbtrV6h'},
#  {'album_id': '2hAEtuIjQY3znPERGscedA',
#   'name': 'Castle of Sand',
#   'release_date': '2025-07-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2hAEtuIjQY3znPERGscedA'},
#  {'album_id': '6YKpsz7cV1ddXpU2G4Tasd',
#   'name': "Knockin' On Heaven's Door",
#   'release_date': '2025-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6YKpsz7cV1ddXpU2G4Tasd'},
#  {'album_id': '5OuoTMMoEFOUGp4gGzIu24',
#   'name': 'Lounge Bar Jamming',
#   'release_date': '2025-07-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5OuoTMMoEFOUGp4gGzIu24'},
#  {'album_id': '37drgKvxPJqLmf9fTeY8dt',
#   'name': 'Turn Me On',
#   'release_date': '2025-03-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/37drgKvxPJqLmf9fTeY8dt'},
#  {'album_id': '1neZ6WI8HxQp0DBdIlRZ0d',
#   'name': 'Late Nights',
#   'release_date': '2025-05-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1neZ6WI8HxQp0DBdIlRZ0d'},
#  {'album_id': '3zfRhTVRmaCYv3FcvlQ3XY',
#   'name': "I Won't Give Up",
#   'release_date': '2025-02-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3zfRhTVRmaCYv3FcvlQ3XY'},
#  {'album_id': '7vNlhj83RHZNPekQFxewCb',
#   'name': 'Fløwee',
#   'release_date': '2025-06-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7vNlhj83RHZNPekQFxewCb'},
#  {'album_id': '1c1rycnntYRaMDsHlve8Nb',
#   'name': 'Use Somebody',
#   'release_date': '2025-07-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1c1rycnntYRaMDsHlve8Nb'},
#  {'album_id': '1s9Ay4yhnmtHyYZE7MD2ZQ',
#   'name': 'Blinding Lights',
#   'release_date': '2024-09-05',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/1s9Ay4yhnmtHyYZE7MD2ZQ'},
#  {'album_id': '3LwuvoyC3KrHqx6595MOHM',
#   'name': 'Sunrise',
#   'release_date': '2025-07-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3LwuvoyC3KrHqx6595MOHM'},
#  {'album_id': '2FwAojrL0dLm3g07ahf1YB',
#   'name': 'Closer',
#   'release_date': '2025-04-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2FwAojrL0dLm3g07ahf1YB'},
#  {'album_id': '2KBwt30EusMlbsRNiGKTvK',
#   'name': "We Don't Talk Anymore",
#   'release_date': '2024-11-08',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/2KBwt30EusMlbsRNiGKTvK'},
#  {'album_id': '75fipqCtxQWvDRkHWdznc2',
#   'name': 'I Had Some Help',
#   'release_date': '2025-06-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/75fipqCtxQWvDRkHWdznc2'},
#  {'album_id': '1iEzia2cnr3wWjgRKwtLUo',
#   'name': 'Soft Cream',
#   'release_date': '2025-02-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1iEzia2cnr3wWjgRKwtLUo'},
#  {'album_id': '53ogawwq7syDhSt9BiowcF',
#   'name': 'Enemy',
#   'release_date': '2024-03-28',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/53ogawwq7syDhSt9BiowcF'},
#  {'album_id': '6WTi9NbC4buNFSpDI0uKnt',
#   'name': 'Savannah',
#   'release_date': '2025-04-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6WTi9NbC4buNFSpDI0uKnt'},
#  {'album_id': '50TIiMeLS90TfE4Cym3aDQ',
#   'name': 'THATS WHAT I WANT',
#   'release_date': '2024-02-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/50TIiMeLS90TfE4Cym3aDQ'},
#  {'album_id': '7JPfpnK1DtbriOOIvwXxaN',
#   'name': 'Polar Hush',
#   'release_date': '2025-02-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7JPfpnK1DtbriOOIvwXxaN'},
#  {'album_id': '1pj5YvxWkDZMunHMZHbipe',
#   'name': 'Silent Echoes',
#   'release_date': '2025-05-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1pj5YvxWkDZMunHMZHbipe'},
#  {'album_id': '5qZF8KrTtjzLt0QK2WpkB9',
#   'name': 'Sunset Breeze',
#   'release_date': '2025-07-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5qZF8KrTtjzLt0QK2WpkB9'},
#  {'album_id': '3Gr4ZDkAoxbF6Q7QI5UZRJ',
#   'name': 'Une Nuit En Ville',
#   'release_date': '2025-01-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Gr4ZDkAoxbF6Q7QI5UZRJ'},
#  {'album_id': '2GeDbZD8sPjU8BBwoiYS1E',
#   'name': 'Nova',
#   'release_date': '2025-04-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2GeDbZD8sPjU8BBwoiYS1E'},
#  {'album_id': '5GicafZtl7JPeGXoGnPRzY',
#   'name': 'Silent Oak',
#   'release_date': '2025-01-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5GicafZtl7JPeGXoGnPRzY'},
#  {'album_id': '2UZJNvw3FJxsABTj7ZTvQ6',
#   'name': 'Daisy Beats',
#   'release_date': '2025-07-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2UZJNvw3FJxsABTj7ZTvQ6'},
#  {'album_id': '1evGMVLWKiRsoZfnwGKMvf',
#   'name': 'Love Everyday',
#   'release_date': '2025-06-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1evGMVLWKiRsoZfnwGKMvf'},
#  {'album_id': '5OstA6qbB75LoJpduHlwBW',
#   'name': 'Lemon Haze',
#   'release_date': '2025-06-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5OstA6qbB75LoJpduHlwBW'},
#  {'album_id': '2Q2fOqrBQjsv0GBjY3T1tE',
#   'name': 'Hop Some Fences',
#   'release_date': '2025-06-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2Q2fOqrBQjsv0GBjY3T1tE'},
#  {'album_id': '33i9qCAwKfVEO1sGc2a10t',
#   'name': 'Sugar Loops',
#   'release_date': '2025-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/33i9qCAwKfVEO1sGc2a10t'},
#  {'album_id': '5T5KWViwtnOidQT4RuBBuw',
#   'name': 'Wanna Go Surfin’',
#   'release_date': '2025-06-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5T5KWViwtnOidQT4RuBBuw'},
#  {'album_id': '0bANOxLRs8jQ5NRQMu0aVV',
#   'name': 'Bright Tones',
#   'release_date': '2025-07-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0bANOxLRs8jQ5NRQMu0aVV'},
#  {'album_id': '2b3NjgTUK5Z0mYsQIiV9Fc',
#   'name': 'Sweet Little Flower',
#   'release_date': '2025-04-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2b3NjgTUK5Z0mYsQIiV9Fc'},
#  {'album_id': '0Sy9TpeJnSDpT2ajERT7p1',
#   'name': 'Starry Swing',
#   'release_date': '2025-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0Sy9TpeJnSDpT2ajERT7p1'},
#  {'album_id': '2lOePbj6Wp5Y3OMHiGAq1f',
#   'name': 'The Blissful Jam',
#   'release_date': '2025-05-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2lOePbj6Wp5Y3OMHiGAq1f'},
#  {'album_id': '10Ev4dKwAQVk0WGlq6gOjZ',
#   'name': 'Sun-Kissed Rhythms',
#   'release_date': '2025-05-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10Ev4dKwAQVk0WGlq6gOjZ'},
#  {'album_id': '2qZRpgJANt8YCQ5dySy68P',
#   'name': 'Amber Moon',
#   'release_date': '2025-07-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2qZRpgJANt8YCQ5dySy68P'},
#  {'album_id': '110sy4uTtnFToEy9W9IGYE',
#   'name': 'Driftwood Funk',
#   'release_date': '2025-05-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/110sy4uTtnFToEy9W9IGYE'},
#  {'album_id': '615DCMpoWoA9hZPpRgX6Zo',
#   'name': 'Horizon Hues',
#   'release_date': '2025-06-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/615DCMpoWoA9hZPpRgX6Zo'},
#  {'album_id': '1rPMaREtyHtUL5fNWAvnGJ',
#   'name': 'Smooth Sailing',
#   'release_date': '2025-05-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1rPMaREtyHtUL5fNWAvnGJ'},
#  {'album_id': '2zv9SN933u9Lw0aXWHgYUY',
#   'name': 'Mellow Mirage',
#   'release_date': '2025-07-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2zv9SN933u9Lw0aXWHgYUY'},
#  {'album_id': '4vBAuiAfAHeduzOHQhwwoj',
#   'name': 'Skyline Groove',
#   'release_date': '2025-06-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4vBAuiAfAHeduzOHQhwwoj'},
#  {'album_id': '3LFY5XrjHkZRgE5F2em35i',
#   'name': 'Mango Breeze',
#   'release_date': '2025-07-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3LFY5XrjHkZRgE5F2em35i'},
#  {'album_id': '5sCQv65jKWCBoZWGmDl0so',
#   'name': 'Sundown Serenade',
#   'release_date': '2025-06-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5sCQv65jKWCBoZWGmDl0so'},
#  {'album_id': '5UvYau4CldkeJ3DeOYoZsr',
#   'name': 'Sunkissed Soul',
#   'release_date': '2025-06-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5UvYau4CldkeJ3DeOYoZsr'},
#  {'album_id': '7aSvqx3eqTJGbEPMAZkjyh',
#   'name': 'Citrus Swing',
#   'release_date': '2025-07-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7aSvqx3eqTJGbEPMAZkjyh'},
#  {'album_id': '4lXO4gUEEoVfF0cMvQ3gfx',
#   'name': 'Golden Hour Groove',
#   'release_date': '2025-05-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4lXO4gUEEoVfF0cMvQ3gfx'},
#  {'album_id': '4ZsHTG5HCUPGjKYj2ik6qc',
#   'name': 'Coastal Breeze',
#   'release_date': '2025-05-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ZsHTG5HCUPGjKYj2ik6qc'},
#  {'album_id': '2ce45SS3NLr0dU8JfIyn92',
#   'name': 'Velvet Skies',
#   'release_date': '2025-05-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2ce45SS3NLr0dU8JfIyn92'},
#  {'album_id': '6KmfoZQYpwirZlvlfZYcaH',
#   'name': 'Let Us Shine',
#   'release_date': '2025-04-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6KmfoZQYpwirZlvlfZYcaH'},
#  {'album_id': '5MFFvN3uuAfsoJrDzLJKJE',
#   'name': 'Groovy Haze',
#   'release_date': '2025-06-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5MFFvN3uuAfsoJrDzLJKJE'},
#  {'album_id': '2k2K6spth1uN3yEecZtDxr',
#   'name': 'Getting Saxy',
#   'release_date': '2025-05-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2k2K6spth1uN3yEecZtDxr'},
#  {'album_id': '00J7GRRHpT5j33UyRGagzp',
#   'name': 'Punta',
#   'release_date': '2025-04-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/00J7GRRHpT5j33UyRGagzp'},
#  {'album_id': '0oeC0VU75ZbuqwbznT6eMB',
#   'name': 'Lately',
#   'release_date': '2025-02-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0oeC0VU75ZbuqwbznT6eMB'},
#  {'album_id': '67gfc3acmvuCAgxXc6sAzB',
#   'name': 'Good Morning',
#   'release_date': '2025-05-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/67gfc3acmvuCAgxXc6sAzB'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6piO5Ac23WJnRQifD42dfv'},
#   'href': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv',
#   'id': '6piO5Ac23WJnRQifD42dfv',
#   'name': 'Peaceful Melody',
#   'type': 'artist',
#   'uri': 'spotify:artist:6piO5Ac23WJnRQifD42dfv'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0QuTX3mzksvtwoQru6tiF8'},
#   'href': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8',
#   'id': '0QuTX3mzksvtwoQru6tiF8',
#   'name': 'soave lofi',
#   'type': 'artist',
#   'uri': 'spotify:artist:0QuTX3mzksvtwoQru6tiF8'}]

# %%
artist_list= []
for row in data['items']:
    for key, value in row.items():
        if key =="track":
          for artist in value['artists']:
              artist_dict= {'artist_id':artist ['id'],'artist_name':artist['name'], 'external_url': artist['href'] }
              artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '62cuL0WEl5MhPlrmkOx6TT',
#   'artist_name': 'mininova',
#   'external_url': 'https://api.spotify.com/v1/artists/62cuL0WEl5MhPlrmkOx6TT'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '0Zl7gxlHCKNJeHamhYyE1c',
#   'artist_name': 'suroboi',
#   'external_url': 'https://api.spotify.com/v1/artists/0Zl7gxlHCKNJeHamhYyE1c'},
#  {'artist_id': '0rqcFCJETiydyHx7rMg7jx',
#   'artist_name': 'Chill Jam',
#   'external_url': 'https://api.spotify.com/v1/artists/0rqcFCJETiydyHx7rMg7jx'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '0Zl7gxlHCKNJeHamhYyE1c',
#   'artist_name': 'suroboi',
#   'external_url': 'https://api.spotify.com/v1/artists/0Zl7gxlHCKNJeHamhYyE1c'},
#  {'artist_id': '0rqcFCJETiydyHx7rMg7jx',
#   'artist_name': 'Chill Jam',
#   'external_url': 'https://api.spotify.com/v1/artists/0rqcFCJETiydyHx7rMg7jx'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '21zky5Q21cXOpPlec8XnM6',
#   'artist_name': 'SPUDB',
#   'external_url': 'https://api.spotify.com/v1/artists/21zky5Q21cXOpPlec8XnM6'},
#  {'artist_id': '1wWqLuYdmHGPlO16jo9ahp',
#   'artist_name': 'George Karayiannis',
#   'external_url': 'https://api.spotify.com/v1/artists/1wWqLuYdmHGPlO16jo9ahp'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '2TeP8zIsRQbxp6Lwc47C8v',
#   'artist_name': 'The French Monarch',
#   'external_url': 'https://api.spotify.com/v1/artists/2TeP8zIsRQbxp6Lwc47C8v'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7rQLe2WL8bB39ZbuQOAI09',
#   'artist_name': 'aprilor',
#   'external_url': 'https://api.spotify.com/v1/artists/7rQLe2WL8bB39ZbuQOAI09'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '4bWUSOEk4qhaAM251pddKo',
#   'artist_name': 'Juju BB',
#   'external_url': 'https://api.spotify.com/v1/artists/4bWUSOEk4qhaAM251pddKo'},
#  {'artist_id': '5l1oiy2VufzI1tbdpiaoQi',
#   'artist_name': 'Lucid Keys',
#   'external_url': 'https://api.spotify.com/v1/artists/5l1oiy2VufzI1tbdpiaoQi'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '4bWUSOEk4qhaAM251pddKo',
#   'artist_name': 'Juju BB',
#   'external_url': 'https://api.spotify.com/v1/artists/4bWUSOEk4qhaAM251pddKo'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5ge3dpwYpY032pECjX2fcq',
#   'artist_name': 'gainsome',
#   'external_url': 'https://api.spotify.com/v1/artists/5ge3dpwYpY032pECjX2fcq'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5sKybMcvVtsr7PXQk5xAsL',
#   'artist_name': 'Sweetboikyle',
#   'external_url': 'https://api.spotify.com/v1/artists/5sKybMcvVtsr7PXQk5xAsL'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '3X4HJ5umPM7L9AdqSwBEjh',
#   'artist_name': 'sleen.',
#   'external_url': 'https://api.spotify.com/v1/artists/3X4HJ5umPM7L9AdqSwBEjh'},
#  {'artist_id': '2YCuSc5zthk5gzM054mLOf',
#   'artist_name': 'MOOD boy',
#   'external_url': 'https://api.spotify.com/v1/artists/2YCuSc5zthk5gzM054mLOf'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '2f4COA6IKZu722NBWix5od',
#   'artist_name': 'PBdR',
#   'external_url': 'https://api.spotify.com/v1/artists/2f4COA6IKZu722NBWix5od'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '4YSua4qFdfh8JgRxOW9EoC',
#   'artist_name': 'Tolan',
#   'external_url': 'https://api.spotify.com/v1/artists/4YSua4qFdfh8JgRxOW9EoC'},
#  {'artist_id': '4EUMzs3VfIVjB5yrHv153S',
#   'artist_name': 'Erwin Do',
#   'external_url': 'https://api.spotify.com/v1/artists/4EUMzs3VfIVjB5yrHv153S'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5JWChP6Y4Ae3sQ0FQeviKY',
#   'artist_name': 'Mister Decaf',
#   'external_url': 'https://api.spotify.com/v1/artists/5JWChP6Y4Ae3sQ0FQeviKY'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7hwWfUVrKczeyLavJykzzL',
#   'artist_name': 'Sweet Oscar',
#   'external_url': 'https://api.spotify.com/v1/artists/7hwWfUVrKczeyLavJykzzL'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1I8vSPgZriud0yvXK55JHt',
#   'artist_name': 'vlows',
#   'external_url': 'https://api.spotify.com/v1/artists/1I8vSPgZriud0yvXK55JHt'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '07YwFEZfj3G4ZRQ08iFDAM',
#   'artist_name': 'yourneighborsclassicbeats',
#   'external_url': 'https://api.spotify.com/v1/artists/07YwFEZfj3G4ZRQ08iFDAM'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '0Zl7gxlHCKNJeHamhYyE1c',
#   'artist_name': 'suroboi',
#   'external_url': 'https://api.spotify.com/v1/artists/0Zl7gxlHCKNJeHamhYyE1c'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '0rqcFCJETiydyHx7rMg7jx',
#   'artist_name': 'Chill Jam',
#   'external_url': 'https://api.spotify.com/v1/artists/0rqcFCJETiydyHx7rMg7jx'},
#  {'artist_id': '1RIDuulMVv3vmkanZeYVq4',
#   'artist_name': 'Lō-fÿkkø',
#   'external_url': 'https://api.spotify.com/v1/artists/1RIDuulMVv3vmkanZeYVq4'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '0Zl7gxlHCKNJeHamhYyE1c',
#   'artist_name': 'suroboi',
#   'external_url': 'https://api.spotify.com/v1/artists/0Zl7gxlHCKNJeHamhYyE1c'},
#  {'artist_id': '0rqcFCJETiydyHx7rMg7jx',
#   'artist_name': 'Chill Jam',
#   'external_url': 'https://api.spotify.com/v1/artists/0rqcFCJETiydyHx7rMg7jx'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '3X4HJ5umPM7L9AdqSwBEjh',
#   'artist_name': 'sleen.',
#   'external_url': 'https://api.spotify.com/v1/artists/3X4HJ5umPM7L9AdqSwBEjh'},
#  {'artist_id': '2YCuSc5zthk5gzM054mLOf',
#   'artist_name': 'MOOD boy',
#   'external_url': 'https://api.spotify.com/v1/artists/2YCuSc5zthk5gzM054mLOf'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '4YSua4qFdfh8JgRxOW9EoC',
#   'artist_name': 'Tolan',
#   'external_url': 'https://api.spotify.com/v1/artists/4YSua4qFdfh8JgRxOW9EoC'},
#  {'artist_id': '6e4SoZqhV4nKK3pT2JNrkx',
#   'artist_name': 'Pryces',
#   'external_url': 'https://api.spotify.com/v1/artists/6e4SoZqhV4nKK3pT2JNrkx'},
#  {'artist_id': '4KZj9rS07i3nfijzVtkqMQ',
#   'artist_name': 'saint rumi',
#   'external_url': 'https://api.spotify.com/v1/artists/4KZj9rS07i3nfijzVtkqMQ'},
#  {'artist_id': '6piO5Ac23WJnRQifD42dfv',
#   'artist_name': 'Peaceful Melody',
#   'external_url': 'https://api.spotify.com/v1/artists/6piO5Ac23WJnRQifD42dfv'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5gigjnekB1RsPwKKitalWD',
#   'artist_name': 'GlobulDub',
#   'external_url': 'https://api.spotify.com/v1/artists/5gigjnekB1RsPwKKitalWD'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '2Tc7q1cWJbxcv8Jzjebp0g',
#   'artist_name': 'Twotrees',
#   'external_url': 'https://api.spotify.com/v1/artists/2Tc7q1cWJbxcv8Jzjebp0g'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7HOzX0doXJ8YWE61LUUy5P',
#   'artist_name': 'Blisswave',
#   'external_url': 'https://api.spotify.com/v1/artists/7HOzX0doXJ8YWE61LUUy5P'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '2ERrGspEfSe1sycxXBU48l',
#   'artist_name': 'Picture Talk',
#   'external_url': 'https://api.spotify.com/v1/artists/2ERrGspEfSe1sycxXBU48l'},
#  {'artist_id': '1DFuldQROQAcq0eNiilcUm',
#   'artist_name': 'Lucifurr',
#   'external_url': 'https://api.spotify.com/v1/artists/1DFuldQROQAcq0eNiilcUm'},
#  {'artist_id': '6H52XHsK270xEHnxCpVKat',
#   'artist_name': 'TwoChills',
#   'external_url': 'https://api.spotify.com/v1/artists/6H52XHsK270xEHnxCpVKat'},
#  {'artist_id': '2Tc7q1cWJbxcv8Jzjebp0g',
#   'artist_name': 'Twotrees',
#   'external_url': 'https://api.spotify.com/v1/artists/2Tc7q1cWJbxcv8Jzjebp0g'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5gigjnekB1RsPwKKitalWD',
#   'artist_name': 'GlobulDub',
#   'external_url': 'https://api.spotify.com/v1/artists/5gigjnekB1RsPwKKitalWD'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7HOzX0doXJ8YWE61LUUy5P',
#   'artist_name': 'Blisswave',
#   'external_url': 'https://api.spotify.com/v1/artists/7HOzX0doXJ8YWE61LUUy5P'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '4bWUSOEk4qhaAM251pddKo',
#   'artist_name': 'Juju BB',
#   'external_url': 'https://api.spotify.com/v1/artists/4bWUSOEk4qhaAM251pddKo'},
#  {'artist_id': '6H52XHsK270xEHnxCpVKat',
#   'artist_name': 'TwoChills',
#   'external_url': 'https://api.spotify.com/v1/artists/6H52XHsK270xEHnxCpVKat'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7HOzX0doXJ8YWE61LUUy5P',
#   'artist_name': 'Blisswave',
#   'external_url': 'https://api.spotify.com/v1/artists/7HOzX0doXJ8YWE61LUUy5P'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '13Z78tf8milV5V0tcNwVq0',
#   'artist_name': 'Moon Ghetto',
#   'external_url': 'https://api.spotify.com/v1/artists/13Z78tf8milV5V0tcNwVq0'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7HOzX0doXJ8YWE61LUUy5P',
#   'artist_name': 'Blisswave',
#   'external_url': 'https://api.spotify.com/v1/artists/7HOzX0doXJ8YWE61LUUy5P'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7mgKw7ZHIuDWmXcGuU4vM7',
#   'artist_name': 'Dusty Flames',
#   'external_url': 'https://api.spotify.com/v1/artists/7mgKw7ZHIuDWmXcGuU4vM7'},
#  {'artist_id': '3ARvFGBfNt9K1SIDM9yMwu',
#   'artist_name': 'Cosmic Koala',
#   'external_url': 'https://api.spotify.com/v1/artists/3ARvFGBfNt9K1SIDM9yMwu'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '7HOzX0doXJ8YWE61LUUy5P',
#   'artist_name': 'Blisswave',
#   'external_url': 'https://api.spotify.com/v1/artists/7HOzX0doXJ8YWE61LUUy5P'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1jXT1b0mGSoneZuX4AHSqa',
#   'artist_name': 'Paleni',
#   'external_url': 'https://api.spotify.com/v1/artists/1jXT1b0mGSoneZuX4AHSqa'},
#  {'artist_id': '24snO5m4Z01DjKf5gtl14T',
#   'artist_name': 'Fred Paci',
#   'external_url': 'https://api.spotify.com/v1/artists/24snO5m4Z01DjKf5gtl14T'},
#  {'artist_id': '3PplCjTWQ2AbTboXJNCpSa',
#   'artist_name': 'Lenny B',
#   'external_url': 'https://api.spotify.com/v1/artists/3PplCjTWQ2AbTboXJNCpSa'},
#  {'artist_id': '78MUNs6p8q3sPazy4QaURp',
#   'artist_name': 'Golden Groove',
#   'external_url': 'https://api.spotify.com/v1/artists/78MUNs6p8q3sPazy4QaURp'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '3TT0B5oFY5OcFmaFp1MMyM',
#   'artist_name': 'Lofi Duck',
#   'external_url': 'https://api.spotify.com/v1/artists/3TT0B5oFY5OcFmaFp1MMyM'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1YFHT24tIgrolo6qKnXfVd',
#   'artist_name': 'Sunset Jive',
#   'external_url': 'https://api.spotify.com/v1/artists/1YFHT24tIgrolo6qKnXfVd'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1S1kTJDmdnv2ortw891Wth',
#   'artist_name': 'Honey Flow',
#   'external_url': 'https://api.spotify.com/v1/artists/1S1kTJDmdnv2ortw891Wth'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '78MUNs6p8q3sPazy4QaURp',
#   'artist_name': 'Golden Groove',
#   'external_url': 'https://api.spotify.com/v1/artists/78MUNs6p8q3sPazy4QaURp'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1YFHT24tIgrolo6qKnXfVd',
#   'artist_name': 'Sunset Jive',
#   'external_url': 'https://api.spotify.com/v1/artists/1YFHT24tIgrolo6qKnXfVd'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '78MUNs6p8q3sPazy4QaURp',
#   'artist_name': 'Golden Groove',
#   'external_url': 'https://api.spotify.com/v1/artists/78MUNs6p8q3sPazy4QaURp'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1S1kTJDmdnv2ortw891Wth',
#   'artist_name': 'Honey Flow',
#   'external_url': 'https://api.spotify.com/v1/artists/1S1kTJDmdnv2ortw891Wth'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1YFHT24tIgrolo6qKnXfVd',
#   'artist_name': 'Sunset Jive',
#   'external_url': 'https://api.spotify.com/v1/artists/1YFHT24tIgrolo6qKnXfVd'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '78MUNs6p8q3sPazy4QaURp',
#   'artist_name': 'Golden Groove',
#   'external_url': 'https://api.spotify.com/v1/artists/78MUNs6p8q3sPazy4QaURp'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1S1kTJDmdnv2ortw891Wth',
#   'artist_name': 'Honey Flow',
#   'external_url': 'https://api.spotify.com/v1/artists/1S1kTJDmdnv2ortw891Wth'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '78MUNs6p8q3sPazy4QaURp',
#   'artist_name': 'Golden Groove',
#   'external_url': 'https://api.spotify.com/v1/artists/78MUNs6p8q3sPazy4QaURp'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1YFHT24tIgrolo6qKnXfVd',
#   'artist_name': 'Sunset Jive',
#   'external_url': 'https://api.spotify.com/v1/artists/1YFHT24tIgrolo6qKnXfVd'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1S1kTJDmdnv2ortw891Wth',
#   'artist_name': 'Honey Flow',
#   'external_url': 'https://api.spotify.com/v1/artists/1S1kTJDmdnv2ortw891Wth'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1YFHT24tIgrolo6qKnXfVd',
#   'artist_name': 'Sunset Jive',
#   'external_url': 'https://api.spotify.com/v1/artists/1YFHT24tIgrolo6qKnXfVd'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1S1kTJDmdnv2ortw891Wth',
#   'artist_name': 'Honey Flow',
#   'external_url': 'https://api.spotify.com/v1/artists/1S1kTJDmdnv2ortw891Wth'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1VsZq5rWtH7U1E3M2lpud2',
#   'artist_name': 'Psylone',
#   'external_url': 'https://api.spotify.com/v1/artists/1VsZq5rWtH7U1E3M2lpud2'},
#  {'artist_id': '5pTqDNiEoLwzpjkW05ygeN',
#   'artist_name': 'moon.walken',
#   'external_url': 'https://api.spotify.com/v1/artists/5pTqDNiEoLwzpjkW05ygeN'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '1S1kTJDmdnv2ortw891Wth',
#   'artist_name': 'Honey Flow',
#   'external_url': 'https://api.spotify.com/v1/artists/1S1kTJDmdnv2ortw891Wth'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5sKybMcvVtsr7PXQk5xAsL',
#   'artist_name': 'Sweetboikyle',
#   'external_url': 'https://api.spotify.com/v1/artists/5sKybMcvVtsr7PXQk5xAsL'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '5ge3dpwYpY032pECjX2fcq',
#   'artist_name': 'gainsome',
#   'external_url': 'https://api.spotify.com/v1/artists/5ge3dpwYpY032pECjX2fcq'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '4YSua4qFdfh8JgRxOW9EoC',
#   'artist_name': 'Tolan',
#   'external_url': 'https://api.spotify.com/v1/artists/4YSua4qFdfh8JgRxOW9EoC'},
#  {'artist_id': '4EUMzs3VfIVjB5yrHv153S',
#   'artist_name': 'Erwin Do',
#   'external_url': 'https://api.spotify.com/v1/artists/4EUMzs3VfIVjB5yrHv153S'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'},
#  {'artist_id': '6ClyCKJJ6xSWiWThHm2INh',
#   'artist_name': 'Kumotora',
#   'external_url': 'https://api.spotify.com/v1/artists/6ClyCKJJ6xSWiWThHm2INh'},
#  {'artist_id': '0QuTX3mzksvtwoQru6tiF8',
#   'artist_name': 'soave lofi',
#   'external_url': 'https://api.spotify.com/v1/artists/0QuTX3mzksvtwoQru6tiF8'}]

# %%
song_list = []
for row in data ['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row ['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['track']['album']['id']
    album_id = row['track']['album']['id']
    artist_id= row ['track']['album']['artists'][0]['id']
    song_element = {'song_id ':song_id , 'song_name ':song_name ,'duration_ms':song_duration, 'url':song_url, 'popularity':song_popularity, 'song_added ':song_added ,' album_id ': album_id ,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_element
# Out:
# {'song_id ': '3dorpfoyp7BFEsVauB7llI',
#  'song_name ': 'Good Morning',
#  'duration_ms': 150374,
#  'url': 'https://open.spotify.com/track/3dorpfoyp7BFEsVauB7llI',
#  'popularity': 41,
#  'song_added ': '67gfc3acmvuCAgxXc6sAzB',
#  ' album_id ': '67gfc3acmvuCAgxXc6sAzB',
#  'artist_id': '6ClyCKJJ6xSWiWThHm2INh'}

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                        name  \
# 0  2LnqsGJJZlzAr980A4facE                 I Like You (A Happier Song)
# 1  2wd0Yajm2aZnG3uAYStKXz                                 Lonewalking
# 2  6FG36OzCS7uliuAGGgFUku                                   Strangers
# 3  0PRK8Gt08ZYl5XrxHF8KDm  I Still Haven't Found What I'm Looking For
# 4  0XJhqJBxqsGk5dJ10T5Hza                                Stolen Dance
#
#   release_date  total_tracks  \
# 0   2024-02-15             1
# 1   2023-12-21             1
# 2   2024-11-15             1
# 3   2024-11-29             2
# 4   2024-11-29             1
#
#                                                  url
# 0  https://open.spotify.com/album/2LnqsGJJZlzAr98...
# 1  https://open.spotify.com/album/2wd0Yajm2aZnG3u...
# 2  https://open.spotify.com/album/6FG36OzCS7uliuA...
# 3  https://open.spotify.com/album/0PRK8Gt08ZYl5Xr...
# 4  https://open.spotify.com/album/0XJhqJBxqsGk5dJ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id      artist_name  \
# 0    6piO5Ac23WJnRQifD42dfv  Peaceful Melody
# 1    0QuTX3mzksvtwoQru6tiF8       soave lofi
# 2    62cuL0WEl5MhPlrmkOx6TT         mininova
# 3    0QuTX3mzksvtwoQru6tiF8       soave lofi
# 4    6piO5Ac23WJnRQifD42dfv  Peaceful Melody
# ..                      ...              ...
# 208  4YSua4qFdfh8JgRxOW9EoC            Tolan
# 209  4EUMzs3VfIVjB5yrHv153S         Erwin Do
# 210  0QuTX3mzksvtwoQru6tiF8       soave lofi
# 211  6ClyCKJJ6xSWiWThHm2INh         Kumotora
# 212  0QuTX3mzksvtwoQru6tiF8       soave lofi
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/6piO5Ac23WJ...
# 1    https://api.spotify.com/v1/artists/0QuTX3mzksv...
# 2    https://api.spotify.com/v1/artists/62cuL0WEl5M...
# 3    https://api.spotify.com/v1/artists/0QuTX3mzksv...
# 4    https://api.spotify.com/v1/artists/6piO5Ac23WJ...
# ..                                                 ...
# 208  https://api.spotify.com/v1/artists/4YSua4qFdfh...
# 209  https://api.spotify.com/v1/artists/4EUMzs3VfIV...
# 210  https://api.spotify.com/v1/artists/0QuTX3mzksv...
# 211  https://api.spotify.com/v1/artists/6ClyCKJJ6xS...
# 212  https://api.spotify.com/v1/artists/0QuTX3mzksv...
#
# [213 rows x 3 columns]

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                   song_id                                          song_name   \
# 0   0gXpyI9UZX3mW0a39tWaDT                        I Like You (A Happier Song)
# 1   30CgtrfdkkhT2U1zbK4OKn                                        Lonewalking
# 2   7rN8k2aI5OmLWMxXVD3VzP                                          Strangers
# 3   0yrlTxrVscYlqTFc0tY4vX  I Still Haven't Found What I'm Looking For - I...
# 4   242vTdmyxM9iaDKqjHrTP4                                       Stolen Dance
# ..                     ...                                                ...
# 95  2kVD8sb9T9zuPi8tsUf5Pp                                        Groovy Haze
# 96  72QEaKbYFtVazGM1mUdljV                                       Getting Saxy
# 97  5XnNw3wLpDmtm5pdPPZhKZ                                              Punta
# 98  5XlicQjIMnZXnEQxZaPgEg                                             Lately
# 99  3dorpfoyp7BFEsVauB7llI                                       Good Morning
#
#     duration_ms                                                url  \
# 0        117272  https://open.spotify.com/track/0gXpyI9UZX3mW0a...
# 1        159861  https://open.spotify.com/track/30CgtrfdkkhT2U1...
# 2        128490  https://open.spotify.com/track/7rN8k2aI5OmLWMx...
# 3        171352  https://open.spotify.com/track/0yrlTxrVscYlqTF...
# 4        143333  https://open.spotify.com/track/242vTdmyxM9iaDK...
# ..          ...                                                ...
# 95       188575  https://open.spotify.com/track/2kVD8sb9T9zuPi8...
# 96       172903  https://open.spotify.com/track/72QEaKbYFtVazGM...
# 97       138937  https://open.spotify.com/track/5XnNw3wLpDmtm5p...
# 98       108750  https://open.spotify.com/track/5XlicQjIMnZXnEQ...
# 99       150374  https://open.spotify.com/track/3dorpfoyp7BFEsV...
#
#     popularity             song_added                album_id   \
# 0           53  2LnqsGJJZlzAr980A4facE  2LnqsGJJZlzAr980A4facE
# 1           48  2wd0Yajm2aZnG3uAYStKXz  2wd0Yajm2aZnG3uAYStKXz
# 2           51  6FG36OzCS7uliuAGGgFUku  6FG36OzCS7uliuAGGgFUku
# 3           47  0PRK8Gt08ZYl5XrxHF8KDm  0PRK8Gt08ZYl5XrxHF8KDm
# 4           50  0XJhqJBxqsGk5dJ10T5Hza  0XJhqJBxqsGk5dJ10T5Hza
# ..         ...                     ...                     ...
# 95          42  5MFFvN3uuAfsoJrDzLJKJE  5MFFvN3uuAfsoJrDzLJKJE
# 96          40  2k2K6spth1uN3yEecZtDxr  2k2K6spth1uN3yEecZtDxr
# 97          40  00J7GRRHpT5j33UyRGagzp  00J7GRRHpT5j33UyRGagzp
# 98          42  0oeC0VU75ZbuqwbznT6eMB  0oeC0VU75ZbuqwbznT6eMB
# 99          41  67gfc3acmvuCAgxXc6sAzB  67gfc3acmvuCAgxXc6sAzB
#
#                  artist_id
# 0   6piO5Ac23WJnRQifD42dfv
# 1   62cuL0WEl5MhPlrmkOx6TT
# 2   6piO5Ac23WJnRQifD42dfv
# 3   0Zl7gxlHCKNJeHamhYyE1c
# 4   6piO5Ac23WJnRQifD42dfv
# ..                     ...
# 95  1S1kTJDmdnv2ortw891Wth
# 96  5sKybMcvVtsr7PXQk5xAsL
# 97  5ge3dpwYpY032pECjX2fcq
# 98  4YSua4qFdfh8JgRxOW9EoC
# 99  6ClyCKJJ6xSWiWThHm2INh
#
# [100 rows x 8 columns]

# %%
album_df.head()
# Out:
#                  album_id                                        name  \
# 0  2LnqsGJJZlzAr980A4facE                 I Like You (A Happier Song)
# 1  2wd0Yajm2aZnG3uAYStKXz                                 Lonewalking
# 2  6FG36OzCS7uliuAGGgFUku                                   Strangers
# 3  0PRK8Gt08ZYl5XrxHF8KDm  I Still Haven't Found What I'm Looking For
# 4  0XJhqJBxqsGk5dJ10T5Hza                                Stolen Dance
#
#   release_date  total_tracks  \
# 0   2024-02-15             1
# 1   2023-12-21             1
# 2   2024-11-15             1
# 3   2024-11-29             2
# 4   2024-11-29             1
#
#                                                  url
# 0  https://open.spotify.com/album/2LnqsGJJZlzAr98...
# 1  https://open.spotify.com/album/2wd0Yajm2aZnG3u...
# 2  https://open.spotify.com/album/6FG36OzCS7uliuA...
# 3  https://open.spotify.com/album/0PRK8Gt08ZYl5Xr...
# 4  https://open.spotify.com/album/0XJhqJBxqsGk5dJ...

# %%
artist_df.head()
# Out:
#                 artist_id      artist_name  \
# 0  6piO5Ac23WJnRQifD42dfv  Peaceful Melody
# 1  0QuTX3mzksvtwoQru6tiF8       soave lofi
# 2  62cuL0WEl5MhPlrmkOx6TT         mininova
# 6  0Zl7gxlHCKNJeHamhYyE1c          suroboi
# 7  0rqcFCJETiydyHx7rMg7jx        Chill Jam
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6piO5Ac23WJ...
# 1  https://api.spotify.com/v1/artists/0QuTX3mzksv...
# 2  https://api.spotify.com/v1/artists/62cuL0WEl5M...
# 6  https://api.spotify.com/v1/artists/0Zl7gxlHCKN...
# 7  https://api.spotify.com/v1/artists/0rqcFCJETiy...

# %%
song_df.head()
# Out:
#                  song_id                                          song_name   \
# 0  0gXpyI9UZX3mW0a39tWaDT                        I Like You (A Happier Song)
# 1  30CgtrfdkkhT2U1zbK4OKn                                        Lonewalking
# 2  7rN8k2aI5OmLWMxXVD3VzP                                          Strangers
# 3  0yrlTxrVscYlqTFc0tY4vX  I Still Haven't Found What I'm Looking For - I...
# 4  242vTdmyxM9iaDKqjHrTP4                                       Stolen Dance
#
#    duration_ms                                                url  popularity  \
# 0       117272  https://open.spotify.com/track/0gXpyI9UZX3mW0a...          53
# 1       159861  https://open.spotify.com/track/30CgtrfdkkhT2U1...          48
# 2       128490  https://open.spotify.com/track/7rN8k2aI5OmLWMx...          51
# 3       171352  https://open.spotify.com/track/0yrlTxrVscYlqTF...          47
# 4       143333  https://open.spotify.com/track/242vTdmyxM9iaDK...          50
#
#               song_added                album_id                artist_id
# 0  2LnqsGJJZlzAr980A4facE  2LnqsGJJZlzAr980A4facE  6piO5Ac23WJnRQifD42dfv
# 1  2wd0Yajm2aZnG3uAYStKXz  2wd0Yajm2aZnG3uAYStKXz  62cuL0WEl5MhPlrmkOx6TT
# 2  6FG36OzCS7uliuAGGgFUku  6FG36OzCS7uliuAGGgFUku  6piO5Ac23WJnRQifD42dfv
# 3  0PRK8Gt08ZYl5XrxHF8KDm  0PRK8Gt08ZYl5XrxHF8KDm  0Zl7gxlHCKNJeHamhYyE1c
# 4  0XJhqJBxqsGk5dJ10T5Hza  0XJhqJBxqsGk5dJ10T5Hza  6piO5Ac23WJnRQifD42dfv

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    datetime64[ns]
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6    album_id    100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB
